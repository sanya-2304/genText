# %% [markdown]
# <a href="https://colab.research.google.com/github/sanya-2304/genText/blob/main/hugging_face_and_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_huggingface
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 91.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from huggingface_hub import InferenceClient
client = InferenceClient(model="mistralai/Mistral-7B-Instruct-v0.2", token=sec_key)

# %%
from google.colab import userdata
sec_key = userdata.get("Hugging_face_token")

# %%
response = client.text_generation(
    "Explain LangChain and its use cases.",
    max_new_tokens=500,  # Increase token limit
    temperature=0.3,  # Lower temp for factual accuracy
    top_p=0.9  # Reduce randomness
)

# %%
print(response)
# Out:
# LangChain is an open-source decentralized AI language model built on the Solana blockchain. It aims to provide a decentralized alternative to centralized AI language models like ChatGPT, Bing, or Google's language models. LangChain uses a consensus-driven approach to train its language model, allowing anyone to contribute to the model's improvement.
#
# LangChain's use cases include:
#
# 1. Decentralized AI language model: LangChain provides a decentralized alternative to centralized AI language models, ensuring data privacy and security while allowing anyone to contribute to the model's improvement.
# 2. Censorship-resistant: LangChain is censorship-resistant, meaning it cannot be shut down or controlled by any single entity. This makes it an ideal solution for users who value free speech and want to avoid potential censorship.
# ...

# %%
client = InferenceClient(model="mistralai/Mistral-7B-Instruct-v0.3", token=sec_key)

response = client.text_generation(
    "What is linkedin and how to get jobs on linkedin?",
    max_new_tokens=500,  # Increase token limit
    temperature=0.3,  # Lower temp for factual accuracy
    top_p=0.9  # Reduce randomness
)

print(response)
# Out:
# LinkedIn is a professional networking platform that allows users to create a profile showcasing their work experience, education, skills, and connections. It is used by millions of professionals worldwide to connect with others in their industry, find job opportunities, and build their professional brand.
#
# To get jobs on LinkedIn, you can follow these steps:
#
# 1. Create a professional profile: Make sure your LinkedIn profile is complete, up-to-date, and tailored to the job you are seeking. Include a professional photo, a clear and concise summary, and detailed work experience and skills.
# 2. Build a network: Connect with people in your industry, former colleagues, and classmates. You can also join LinkedIn groups related to your field to expand your network and gain access to job opportunities.
# 3. Search for jobs: Use the LinkedIn job search feature to find job opportunities that match your skills and interests. You can filter your search by location, industry, and job type.
# ...
